# %%
import pandas as pd 
from matplotlib import pyplot as ppt 
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statistics

# %%
day_sentiment_series = pd.read_csv('Uk Time Series Data Death.csv', index_col=0,
                                      parse_dates=True, squeeze=True)

day_sentiment_series.index
# Out:
# DatetimeIndex(['2019-12-31', '2020-01-01', '2020-02-01', '2020-03-01',
#                '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01',
#                '2020-08-01', '2020-09-01',
#                ...
#                '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
#                '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25',
#                '2020-04-26', '2020-04-27'],
#               dtype='datetime64[ns]', name='dateRep', length=119, freq=None)

# %%
day_sentiment_series.head()
# Out:
# dateRep
# 2019-12-31    0
# 2020-01-01    0
# 2020-02-01    0
# 2020-03-01    0
# 2020-04-01    0
# Name: deaths, dtype: int64

# %%
day_sentiment_series.tail()
# Out:
# dateRep
# 2020-04-23    763
# 2020-04-24    638
# 2020-04-25    768
# 2020-04-26    813
# 2020-04-27    413
# Name: deaths, dtype: int64

# %%
ppt.plot(day_sentiment_series)
ppt.show()

# %%
day_sentiment_series_diff1 = day_sentiment_series.diff().fillna(day_sentiment_series)

# %%
ppt.plot(day_sentiment_series_diff1)
ppt.show()

# %%
day_sentiment_series_diff2 = day_sentiment_series.diff().fillna(day_sentiment_series_diff1)

# %%
ppt.plot(day_sentiment_series_diff2)
ppt.show()

# %%
day_sentiment_series_diff1 = day_sentiment_series.diff().fillna(day_sentiment_series_diff2)

# %%
ppt.plot(day_sentiment_series_diff1)
ppt.show()

# %%
for i in range(10000000000000):
    day_sentiment_series_diff2 = day_sentiment_series.diff().fillna(day_sentiment_series_diff1)
    day_sentiment_series_diff1 = day_sentiment_series.diff().fillna(day_sentiment_series_diff2)
ppt.plot(day_sentiment_series_diff1)
ppt.show()
