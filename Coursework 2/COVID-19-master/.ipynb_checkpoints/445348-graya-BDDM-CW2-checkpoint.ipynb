# %%
import pandas as pd
import numpy as np  
import altair as alt

import matplotlib.pyplot as plt
# %matplotlib inline
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
# Importing the Data
#data = pd.read_excel("editted_data_set.xlsx")

xls = pd.ExcelFile('editted_data_set.xlsx')

all_deaths = pd.read_excel(xls, 'Sheet1')
carona_deaths = pd.read_excel(xls, 'Sheet2')

xls2 = pd.ExcelFile('2019_data.xls')
deaths_2019_total = pd.read_excel(xls2, 'Total')
deaths_2019_Male = pd.read_excel(xls2, 'Male')
deaths_2019_Female = pd.read_excel(xls2, 'Female')

print(all_deaths.head())
# Out:
#    Week Number  <1  1-4  5-9  10-14  15-19  20-24  25-29  30-34  35-39  ...  \
# 0            1  48    8    4      4      6     11     17     32     54  ...
# 1            2  50    9    8      9     16     23     37     46     68  ...
# 2            3  69    7    5      4     10     25     37     47     77  ...
# 3            4  53    9    4      8     15     30     36     38     79  ...
# 4            5  50    6    5      4     23     23     28     58     76  ...
#
#    50-54  55-59  60-64  65-69  70-74  75-79  80-84  85-89   90+  Total
# 0    239    361    486    696   1164   1535   2049   2457  2898  12253
# 1    279    426    604    857   1341   1724   2290   2697  3297  14057
# 2    306    461    562    803   1210   1612   2103   2421  2924  12990
# 3    280    381    535    791   1167   1474   1863   2188  2626  11853
# 4    278    382    525    732   1196   1445   1811   2124  2583  11612
#
# [5 rows x 22 columns]

# %%
from vega_datasets import data

source = data.stocks()

source.head()
# Out:
#   symbol       date  price
# 0   MSFT 2000-01-01  39.81
# 1   MSFT 2000-02-01  36.35
# 2   MSFT 2000-03-01  43.22
# 3   MSFT 2000-04-01  28.37
# 4   MSFT 2000-05-01  25.45

# %%
chart = alt.Chart(df1).mark_line(color='red').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('1-4:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800)

chart2 = alt.Chart(df1).mark_line(color='blue').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('5-9:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart3 = alt.Chart(df1).mark_line(color='green').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('10-14:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart4 = alt.Chart(df1).mark_line(color='orange').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('15-19:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart5 = alt.Chart(df1).mark_line(color='purple').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('20-24:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart6 = alt.Chart(df1).mark_line( color='yellow').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('25-29:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart7 = alt.Chart(df1).mark_line( color='black').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('30-34:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart8 = alt.Chart(df1).mark_line(color='grey').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('35-39:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Date',
    
)
chart9 = alt.Chart(df1).mark_line(color='teal').encode(
    alt.X('Date', scale=alt.Scale(zero=True)),
    alt.Y('Total', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Date',
    
)
chart10 = alt.Chart(df1).mark_line(color='brown').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('40-44:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800)

chart11 = alt.Chart(df1).mark_line(color='warmgrey').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('45-49:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800)

chart12 = alt.Chart(df1).mark_line(color='viridis').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('50-54:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart13 = alt.Chart(df1).mark_line(color='magma').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('55-59:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart14 = alt.Chart(df1).mark_line(color='inferno').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('60-64:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart15 = alt.Chart(df1).mark_line(color='plasma').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('65-69:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart16 = alt.Chart(df1).mark_line( color='bluegreen').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('70-74:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)
chart17 = alt.Chart(df1).mark_line( color='darkpurple').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('75-79:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
)

chart18 = alt.Chart(df1).mark_line(color='darkgreen').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('80-84:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Date',
    
)
chart19 = alt.Chart(df1).mark_line(color='darkgold').encode(
    alt.X('Date', scale=alt.Scale(zero=True)),
    alt.Y('85-89', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Date',
    
)
chart20 = alt.Chart(df1).mark_line(color='gold').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('90+:Q', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800)

chart21 = alt.Chart(df1).mark_line(color='darkred').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('<1', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800,
        height=600
)

# %%
(chart + chart2 + chart3 + chart4 + chart5 + chart6 + 
 chart7 + chart8 + chart10 + chart11 + chart12 + chart13 + chart14 + chart15 + chart16 + 
 chart17 + chart18 + chart19 + chart20 + chart21)

# %%
chart22 = alt.Chart(df1).mark_line(color='green').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('<1', scale=alt.Scale(zero=False),title='Total Deaths'),
    y2 = 'Total',
    order='Date',
).properties(
    width=800,
        height=800
)

chart23 = alt.Chart(df1).mark_line(color='green').encode(
    alt.X('Date', scale=alt.Scale(zero=False)),
    alt.Y('Total', scale=alt.Scale(zero=False),title='Total Deaths'),
    order='Date',
).properties(
    width=800,
        height=800
)

combined = alt.layer(chart23,chart22)
combined.display()

# %%
import numpy as np
import altair as alt
x = np.arange(100)
sin = np.sin(x / 5)
data = pd.DataFrame({'x': x,
                     'sin(x)': np.sin(x / 5),
                     'q_95': sin + 100*np.random.rand(100),
                     'q_75': sin + 75*np.random.rand(100),
                     'q_50': sin + 50*np.random.rand(100),
                     'q_25': sin + 25*np.random.rand(100),
                     'q_05': sin + 5*np.random.rand(100),
                    })
perc_90 = alt.Chart(data).mark_area(color='#4292c6', opacity = .5,).encode(
    x=alt.X('x',axis=alt.Axis(title='Day')),
    y=alt.Y('q_05',axis=alt.Axis(title='cfs')),
    y2 = 'q_95',
    #fill=alt.Color("p90", legend=alt.Legend(title=''))
    
).properties(
    width=800)


perc_50 = alt.Chart(data).mark_area(color='#08519c', opacity = .5).encode(
    x=alt.X('x',axis=alt.Axis(title='Day')),
    y=alt.Y('q_25',axis=alt.Axis(title='cfs')),
    y2 = 'q_75',
    #color=alt.Color("p50", legend=alt.Legend(title=''))
    
)

median = alt.Chart(data).mark_line(color = '#08306b').encode(
    x='x',
    y='q_50',
    #opacity=alt.Color("median", legend=alt.Legend(title=''))
)

perc_90 + perc_50 + median

# %%
total = carona_deaths['Total'] + deaths_2019_total['Total']

all_deaths_chart = alt.Chart(all_deaths).mark_line(color='red').encode(
    alt.X('Week Number', scale=alt.Scale(zero=True)),
    alt.Y('Total', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Week Number',
    
)

carona_deaths_chart = alt.Chart(carona_deaths).mark_line(color='teal').encode(
    alt.X('Week Number', scale=alt.Scale(zero=True)),
    alt.Y('Total', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Week Number',
    
)

all_deaths_2019_chart = alt.Chart(deaths_2019_total).mark_line(color='gold').encode(
    alt.X('Week Number', scale=alt.Scale(zero=True)),
    alt.Y('Total', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Week Number',
    
)

carona_deaths_chart = alt.Chart(carona_deaths).mark_line(color='teal').encode(
    alt.X('Week Number', scale=alt.Scale(zero=True)),
    alt.Y('Total', scale=alt.Scale(zero=True),title='Total Deaths'),
    
    #color=alt.Color('symbol', scale=alt.Scale(range=['red', 'lightgray'], domain=['35-39', '30-34']))
    order='Week Number',
    
)

# %%
(all_deaths_chart + carona_deaths_chart + all_deaths_2019_chart)
