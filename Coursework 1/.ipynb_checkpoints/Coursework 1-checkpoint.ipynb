# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
import scipy.stats
from sklearn import metrics

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %matplotlib inline

# %%
def encode(x):
    if (x <= 0):
        return 0
    elif (x >= 1):
        return 1

# %%
def do_apriori(data, minimum_sup, country=''):

    if country != "":
        basket = (data[data['Country'] == country]
                .groupby(['InvoiceNo', 'Description'])['Quantity']
                .sum().unstack().reset_index().fillna(0)
                .set_index('InvoiceNo'))
     
    else:
        basket = (data.groupby(['InvoiceNo', 'Description'])['Quantity']
                .sum().unstack().reset_index().fillna(0)
                .set_index('InvoiceNo'))

    basket_sets = basket.applymap(encode)

    frequent_itemsets = apriori(basket_sets, min_support=minimum_sup, use_colnames=True)

    return frequent_itemsets

# %% [markdown]
# ## Apriori and Association Rule Functions

# %%
def do_association_rule(data, picked_metric, picked_threshold): 
    return association_rules(data, metric=picked_metric, min_threshold=picked_threshold)

# %% [markdown]
# ## Data Encoding and Visualisation Functions

# %%
def total_count_bar(data, group_by):
    plt.figure(figsize=[10,6])
    data.groupby(group_by).size().plot(kind='bar')
    plt.title('Transactions for each Country')
    plt.xlabel(group_by)    
    plt.ylabel('Total Count')
    plt.plot()

# %% [markdown]
# ## Data Preparation and Retrieval

# %%
# Importing the Data
original_data = pd.read_csv("OnlineRetail.csv")
#print(data)

print('Number of unique Customers:  ', len(original_data.CustomerID.unique()))
print('Number of unique Invoice:    ', len(original_data.InvoiceNo.unique()))
print('Number of unique Stock items:', len(original_data.StockCode.unique()))
print()
print(len(original_data.Country.unique()), 'unique countries:')
print(original_data.Country.value_counts())
# Out:
# Number of unique Customers:   4335
# Number of unique Invoice:     18405
# Number of unique Stock items: 3659
#
# 37 unique countries:
# United Kingdom          354005
# Germany                   8659
# France                    8034
# EIRE                      7138
# Spain                     2423
# Netherlands               2326
# Belgium                   1935
# Switzerland               1811
# Portugal                  1425
# Australia                 1184
# Norway                    1049
# Channel Islands            744
# Italy                      741
# Finland                    647
# Cyprus                     612
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# RSA                         57
# European Community          57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              24
# Bahrain                     17
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
total_count_bar(original_data, 'Country')

#print(total_count_bar('InvoiceNo'))

# %% [markdown]
# ## Analysing whole Dataset

# %%
frequent_items = do_apriori(original_data, 0.02)

frequent_items.head()
# Out:
#     support                           itemsets
# 0  0.021842         (3 STRIPEY MICE FELTCRAFT)
# 1  0.039446           (6 RIBBONS RUSTIC CHARM)
# 2  0.025319  (60 CAKE CASES VINTAGE CHRISTMAS)
# 3  0.035697      (60 TEATIME FAIRY CAKE CASES)
# 4  0.027221   (72 SWEETHEART FAIRY CAKE CASES)

# %%
lift_rules = do_association_rule(frequent_items, "lift", 10)
conf_rules = do_association_rule(frequent_items, "confidence", 0.5)

# %%
#rules.head(10)
conf_rules.sort_values('confidence', ascending = False, inplace = True)
print("Total Confidence count:", len(conf_rules))
conf_rules.head(30)
# Out:
# Total Confidence count: 32
#                                           antecedents  \
# 29  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 28  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 8                    (PINK REGENCY TEACUP AND SAUCER)
# 22                   (PINK REGENCY TEACUP AND SAUCER)
# 10                  (GREEN REGENCY TEACUP AND SAUCER)
# 6                (GARDENERS KNEELING PAD CUP OF TEA )
# 27  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 31                   (PINK REGENCY TEACUP AND SAUCER)
# 11                 (ROSES REGENCY TEACUP AND SAUCER )
# 4                              (DOLLY GIRL LUNCH BOX)
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 23                 (RED HANGING HEART T-LIGHT HOLDER)
# 7                   (GREEN REGENCY TEACUP AND SAUCER)
# 20                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 2                         (ALARM CLOCK BAKELIKE PINK)
# 14                             (JUMBO BAG STRAWBERRY)
# 13                          (JUMBO BAG PINK POLKADOT)
# 5                 (GARDENERS KNEELING PAD KEEP CALM )
# 1                         (ALARM CLOCK BAKELIKE RED )
# 3                               (SPACEBOY LUNCH BOX )
# 25                      (WOODEN FRAME ANTIQUE WHITE )
# 30                  (GREEN REGENCY TEACUP AND SAUCER)
# 17                          (LUNCH BAG PINK POLKADOT)
# 16                           (JUMBO STORAGE BAG SUKI)
# 21                 (ROSES REGENCY TEACUP AND SAUCER )
# 9                   (GREEN REGENCY TEACUP AND SAUCER)
# 24                 (ROSES REGENCY TEACUP AND SAUCER )
# 26                (WOODEN PICTURE FRAME WHITE FINISH)
# 19                               (LUNCH BAG WOODLAND)
# 12                            (HEART OF WICKER LARGE)
#
#                                           consequents  antecedent support  \
# 29                  (GREEN REGENCY TEACUP AND SAUCER)            0.023689
# 28                 (ROSES REGENCY TEACUP AND SAUCER )            0.024993
# 8                   (GREEN REGENCY TEACUP AND SAUCER)            0.030209
# 22                 (ROSES REGENCY TEACUP AND SAUCER )            0.030209
# 10                 (ROSES REGENCY TEACUP AND SAUCER )            0.037544
# 6                 (GARDENERS KNEELING PAD KEEP CALM )            0.034501
# 27                   (PINK REGENCY TEACUP AND SAUCER)            0.029394
# 31  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.030209
# 11                  (GREEN REGENCY TEACUP AND SAUCER)            0.042543
# 4                               (SPACEBOY LUNCH BOX )            0.033469
# 0                         (ALARM CLOCK BAKELIKE RED )            0.042869
# 23               (WHITE HANGING HEART T-LIGHT HOLDER)            0.036892
# 7                    (PINK REGENCY TEACUP AND SAUCER)            0.037544
# 20                  (PAPER CHAIN KIT 50'S CHRISTMAS )            0.037870
# 2                         (ALARM CLOCK BAKELIKE RED )            0.033306
# 14                          (JUMBO BAG RED RETROSPOT)            0.035534
# 13                          (JUMBO BAG RED RETROSPOT)            0.047324
# 5                (GARDENERS KNEELING PAD CUP OF TEA )            0.041076
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.047650
# 3                              (DOLLY GIRL LUNCH BOX)            0.038250
# 25                (WOODEN PICTURE FRAME WHITE FINISH)            0.044064
# 30  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.037544
# 17                          (LUNCH BAG RED RETROSPOT)            0.050584
# 16                          (JUMBO BAG RED RETROSPOT)            0.042054
# 21                   (PINK REGENCY TEACUP AND SAUCER)            0.042543
# 9                          (REGENCY CAKESTAND 3 TIER)            0.037544
# 24                         (REGENCY CAKESTAND 3 TIER)            0.042543
# 26                      (WOODEN FRAME ANTIQUE WHITE )            0.047596
# 19                          (LUNCH BAG RED RETROSPOT)            0.044553
# 12                            (HEART OF WICKER SMALL)            0.043521
#
#     consequent support   support  confidence       lift  leverage  conviction
# 29            0.037544  0.021190    0.894495  23.825164  0.020301    9.122408
# 28            0.042543  0.021190    0.847826  19.928786  0.020127    6.291862
# 8             0.037544  0.024993    0.827338  22.036408  0.023859    5.574223
# 22            0.042543  0.023689    0.784173  18.432564  0.022404    4.436218
# 10            0.042543  0.029394    0.782923  18.403197  0.027797    4.410686
# 6             0.041076  0.025156    0.729134  17.750937  0.023739    3.540214
# 27            0.030209  0.021190    0.720887  23.863183  0.020302    3.474549
# 31            0.029394  0.021190    0.701439  23.863183  0.020302    3.250945
# 11            0.037544  0.029394    0.690932  18.403197  0.027797    3.114062
# 4             0.038250  0.023037    0.688312  17.994853  0.021757    3.085613
# 0             0.047650  0.028797    0.671736  14.097273  0.026754    2.901174
# 23            0.107090  0.024722    0.670103   6.257355  0.020771    2.706632
# 7             0.030209  0.024993    0.665702  22.036408  0.023859    2.900976
# 20            0.053246  0.024504    0.647059  12.152161  0.022488    2.682469
# 2             0.047650  0.021516    0.646003  13.557229  0.019929    2.690279
# 14            0.086933  0.022494    0.633028   7.281795  0.019405    2.488108
# 13            0.086933  0.029666    0.626866   7.210914  0.025552    2.447020
# 5             0.034501  0.025156    0.612434  17.750937  0.023739    2.491184
# 1             0.042869  0.028797    0.604333  14.097273  0.026754    2.419032
# 3             0.033469  0.023037    0.602273  17.994853  0.021757    2.430135
# 25            0.047596  0.025428    0.577065  12.124301  0.023331    2.251895
# 30            0.023689  0.021190    0.564399  23.825164  0.020301    2.241298
# 17            0.069981  0.028416    0.561762   8.027346  0.024876    2.122176
# 16            0.086933  0.023581    0.560724   6.450073  0.019925    2.078570
# 21            0.030209  0.023689    0.556833  18.432564  0.022404    2.188318
# 9             0.092584  0.020321    0.541245   5.846013  0.016845    1.977996
# 24            0.092584  0.022820    0.536398   5.793670  0.018881    1.957320
# 26            0.044064  0.025428    0.534247  12.124301  0.023331    2.052451
# 19            0.069981  0.023526    0.528049   7.545604  0.020408    1.970583
# 12            0.052214  0.022114    0.508115   9.731378  0.019841    1.926844

# %%
lift_rules.sort_values('lift', ascending = False, inplace = True)

print("Total lift count:", len(lift_rules))
lift_rules.head(30)
# Out:
# Total lift count: 24
#                                           antecedents  \
# 18  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 23                   (PINK REGENCY TEACUP AND SAUCER)
# 20  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 21                  (GREEN REGENCY TEACUP AND SAUCER)
# 9                    (PINK REGENCY TEACUP AND SAUCER)
# 8                   (GREEN REGENCY TEACUP AND SAUCER)
# 22                 (ROSES REGENCY TEACUP AND SAUCER )
# 19  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 14                 (ROSES REGENCY TEACUP AND SAUCER )
# 15                   (PINK REGENCY TEACUP AND SAUCER)
# 11                 (ROSES REGENCY TEACUP AND SAUCER )
# 10                  (GREEN REGENCY TEACUP AND SAUCER)
# 5                              (DOLLY GIRL LUNCH BOX)
# 4                               (SPACEBOY LUNCH BOX )
# 7                (GARDENERS KNEELING PAD CUP OF TEA )
# 6                 (GARDENERS KNEELING PAD KEEP CALM )
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE RED )
# 3                         (ALARM CLOCK BAKELIKE RED )
# 2                         (ALARM CLOCK BAKELIKE PINK)
# 12                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 13                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 17                (WOODEN PICTURE FRAME WHITE FINISH)
# 16                      (WOODEN FRAME ANTIQUE WHITE )
#
#                                           consequents  antecedent support  \
# 18                   (PINK REGENCY TEACUP AND SAUCER)            0.029394
# 23  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.030209
# 20                  (GREEN REGENCY TEACUP AND SAUCER)            0.023689
# 21  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.037544
# 9                   (GREEN REGENCY TEACUP AND SAUCER)            0.030209
# 8                    (PINK REGENCY TEACUP AND SAUCER)            0.037544
# 22  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.042543
# 19                 (ROSES REGENCY TEACUP AND SAUCER )            0.024993
# 14                   (PINK REGENCY TEACUP AND SAUCER)            0.042543
# 15                 (ROSES REGENCY TEACUP AND SAUCER )            0.030209
# 11                  (GREEN REGENCY TEACUP AND SAUCER)            0.042543
# 10                 (ROSES REGENCY TEACUP AND SAUCER )            0.037544
# 5                               (SPACEBOY LUNCH BOX )            0.033469
# 4                              (DOLLY GIRL LUNCH BOX)            0.038250
# 7                 (GARDENERS KNEELING PAD KEEP CALM )            0.034501
# 6                (GARDENERS KNEELING PAD CUP OF TEA )            0.041076
# 0                         (ALARM CLOCK BAKELIKE RED )            0.042869
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.047650
# 3                         (ALARM CLOCK BAKELIKE PINK)            0.047650
# 2                         (ALARM CLOCK BAKELIKE RED )            0.033306
# 12                  (PAPER CHAIN KIT 50'S CHRISTMAS )            0.037870
# 13                (PAPER CHAIN KIT VINTAGE CHRISTMAS)            0.053246
# 17                      (WOODEN FRAME ANTIQUE WHITE )            0.047596
# 16                (WOODEN PICTURE FRAME WHITE FINISH)            0.044064
#
#     consequent support   support  confidence       lift  leverage  conviction
# 18            0.030209  0.021190    0.720887  23.863183  0.020302    3.474549
# 23            0.029394  0.021190    0.701439  23.863183  0.020302    3.250945
# 20            0.037544  0.021190    0.894495  23.825164  0.020301    9.122408
# 21            0.023689  0.021190    0.564399  23.825164  0.020301    2.241298
# 9             0.037544  0.024993    0.827338  22.036408  0.023859    5.574223
# 8             0.030209  0.024993    0.665702  22.036408  0.023859    2.900976
# 22            0.024993  0.021190    0.498084  19.928786  0.020127    1.942571
# 19            0.042543  0.021190    0.847826  19.928786  0.020127    6.291862
# 14            0.030209  0.023689    0.556833  18.432564  0.022404    2.188318
# 15            0.042543  0.023689    0.784173  18.432564  0.022404    4.436218
# 11            0.037544  0.029394    0.690932  18.403197  0.027797    3.114062
# 10            0.042543  0.029394    0.782923  18.403197  0.027797    4.410686
# 5             0.038250  0.023037    0.688312  17.994853  0.021757    3.085613
# 4             0.033469  0.023037    0.602273  17.994853  0.021757    2.430135
# 7             0.041076  0.025156    0.729134  17.750937  0.023739    3.540214
# 6             0.034501  0.025156    0.612434  17.750937  0.023739    2.491184
# 0             0.047650  0.028797    0.671736  14.097273  0.026754    2.901174
# 1             0.042869  0.028797    0.604333  14.097273  0.026754    2.419032
# 3             0.033306  0.021516    0.451539  13.557229  0.019929    1.762558
# 2             0.047650  0.021516    0.646003  13.557229  0.019929    2.690279
# 12            0.053246  0.024504    0.647059  12.152161  0.022488    2.682469
# 13            0.037870  0.024504    0.460204  12.152161  0.022488    1.782396
# 17            0.044064  0.025428    0.534247  12.124301  0.023331    2.052451
# 16            0.047596  0.025428    0.577065  12.124301  0.023331    2.251895

# %%
# data.groupby('InvoiceNo').head()

# %%
#frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)
#frequent_itemsets

# %%
#frequent_itemsets = apriori(df, min_support=0.000008, use_colnames=True)

#https://pbpython.com/market-basket-analysis.html

#basket_sets = basket.applymap(encode)

# %% [markdown]
# ## Analysing Individual Countries

# %%
uk_frequent_items = do_apriori(original_data, 0.05, 'United Kingdom')
germany_frequent_items = do_apriori(original_data, 0.05, 'Germany')
france_frequent_items = do_apriori(original_data, 0.05, 'France')
eire_frequent_items = do_apriori(original_data, 0.05, 'EIRE')
spain_frequent_items = do_apriori(original_data, 0.05, 'Spain')
netherlands_frequent_items = do_apriori(original_data, 0.05, 'Netherlands')

# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
# Out:
# '\nUnited Kingdom          354005\nGermany                   8659\nFrance                    8034\nEIRE                      7138\nSpain                     2423\nNetherlands               2326\nBelgium                   1935\nSwitzerland               1811\nPortugal                  1425\nAustralia                 1184\nNorway                    1049\n\n\n'

# %% [markdown]
# ## Individual Countries Association Rule with Lift

# %%
uk_rules = do_association_rule(uk_frequent_items, "lift", 10)

print(len(uk_rules))
uk_rules.head(30)
# Out:
# 20
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE RED )
# 2                (GARDENERS KNEELING PAD CUP OF TEA )
# 3                 (GARDENERS KNEELING PAD KEEP CALM )
# 4                   (GREEN REGENCY TEACUP AND SAUCER)
# 5                    (PINK REGENCY TEACUP AND SAUCER)
# 6                   (GREEN REGENCY TEACUP AND SAUCER)
# 7                  (ROSES REGENCY TEACUP AND SAUCER )
# 8                 (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 9                   (PAPER CHAIN KIT 50'S CHRISTMAS )
# 10                 (ROSES REGENCY TEACUP AND SAUCER )
# 11                   (PINK REGENCY TEACUP AND SAUCER)
# 12                      (WOODEN FRAME ANTIQUE WHITE )
# 13                (WOODEN PICTURE FRAME WHITE FINISH)
# 14  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 15  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 16  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 17                  (GREEN REGENCY TEACUP AND SAUCER)
# 18                 (ROSES REGENCY TEACUP AND SAUCER )
# 19                   (PINK REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                         (ALARM CLOCK BAKELIKE RED )            0.041614
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.045715
# 2                 (GARDENERS KNEELING PAD KEEP CALM )            0.037814
# 3                (GARDENERS KNEELING PAD CUP OF TEA )            0.044750
# 4                    (PINK REGENCY TEACUP AND SAUCER)            0.036910
# 5                   (GREEN REGENCY TEACUP AND SAUCER)            0.029733
# 6                  (ROSES REGENCY TEACUP AND SAUCER )            0.036910
# 7                   (GREEN REGENCY TEACUP AND SAUCER)            0.040890
# 8                   (PAPER CHAIN KIT 50'S CHRISTMAS )            0.040830
# 9                 (PAPER CHAIN KIT VINTAGE CHRISTMAS)            0.056993
# 10                   (PINK REGENCY TEACUP AND SAUCER)            0.040890
# 11                 (ROSES REGENCY TEACUP AND SAUCER )            0.029733
# 12                (WOODEN PICTURE FRAME WHITE FINISH)            0.047283
# 13                      (WOODEN FRAME ANTIQUE WHITE )            0.051505
# 14                   (PINK REGENCY TEACUP AND SAUCER)            0.028708
# 15                 (ROSES REGENCY TEACUP AND SAUCER )            0.024365
# 16                  (GREEN REGENCY TEACUP AND SAUCER)            0.023099
# 17  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.036910
# 18  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.040890
# 19  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.029733
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.045715  0.027381    0.657971  14.392899  0.025478    2.790071
# 1             0.041614  0.027381    0.598945  14.392899  0.025478    2.389660
# 2             0.044750  0.027622    0.730463  16.323179  0.025930    3.544034
# 3             0.037814  0.027622    0.617251  16.323179  0.025930    2.513879
# 4             0.029733  0.024365    0.660131  22.202084  0.023268    2.854825
# 5             0.036910  0.024365    0.819473  22.202084  0.023268    5.334871
# 6             0.040890  0.028708    0.777778  19.021141  0.027198    4.315994
# 7             0.036910  0.028708    0.702065  19.021141  0.027198    3.232551
# 8             0.056993  0.026355    0.645495  11.325873  0.024028    2.660066
# 9             0.040830  0.026355    0.462434  11.325873  0.024028    1.784283
# 10            0.029733  0.023099    0.564897  18.999094  0.021883    2.229970
# 11            0.040890  0.023099    0.776876  18.999094  0.021883    4.298556
# 12            0.051505  0.027622    0.584184  11.342330  0.025187    2.281044
# 13            0.047283  0.027622    0.536300  11.342330  0.025187    2.054597
# 14            0.029733  0.020566    0.716387  24.094129  0.019712    3.421090
# 15            0.040890  0.020566    0.844059  20.642108  0.019569    6.150482
# 16            0.036910  0.020566    0.890339  24.122088  0.019713    8.782466
# 17            0.023099  0.020566    0.557190  24.122088  0.019713    2.206139
# 18            0.024365  0.020566    0.502950  20.642108  0.019569    1.962850
# 19            0.028708  0.020566    0.691684  24.094129  0.019712    3.150310

# %%
germany_rules = do_association_rule(germany_frequent_items, "lift", 5)

print(len(germany_rules))
germany_rules.head(30)
# Out:
# 2
#                      antecedents                    consequents  \
# 0       (WOODLAND CHARLOTTE BAG)  (RED RETROSPOT CHARLOTTE BAG)
# 1  (RED RETROSPOT CHARLOTTE BAG)       (WOODLAND CHARLOTTE BAG)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.130926            0.072235  0.060948    0.465517  6.444504
# 1            0.072235            0.130926  0.060948    0.843750  6.444504
#
#    leverage  conviction
# 0  0.051491    1.735819
# 1  0.051491    5.562077

# %%
france_rules = do_association_rule(france_frequent_items, "lift", 10)

print(len(france_rules))
france_rules.head(30)
# Out:
# 4
#                        antecedents                      consequents  \
# 0    (CHILDRENS CUTLERY SPACEBOY )  (CHILDRENS CUTLERY DOLLY GIRL )
# 1  (CHILDRENS CUTLERY DOLLY GIRL )    (CHILDRENS CUTLERY SPACEBOY )
# 2   (PACK OF 6 SKULL PAPER PLATES)     (PACK OF 6 SKULL PAPER CUPS)
# 3     (PACK OF 6 SKULL PAPER CUPS)   (PACK OF 6 SKULL PAPER PLATES)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.071240            0.073879  0.065963    0.925926  12.533069
# 1            0.073879            0.071240  0.065963    0.892857  12.533069
# 2            0.058047            0.065963  0.052770    0.909091  13.781818
# 3            0.065963            0.058047  0.052770    0.800000  13.781818
#
#    leverage  conviction
# 0  0.060700   12.502639
# 1  0.060700    8.668426
# 2  0.048941   10.274406
# 3  0.048941    4.709763

# %%
eire_rules = do_association_rule(eire_frequent_items, "lift", 10)

print(len(eire_rules))
eire_rules.head(30)
# Out:
# 260
#                                           antecedents  \
# 0                             (REGENCY TEAPOT ROSES )
# 1                          (REGENCY SUGAR BOWL GREEN)
# 2                          (REGENCY TEA PLATE GREEN )
# 3                            (REGENCY TEA PLATE PINK)
# 4   (GREEN REGENCY TEACUP AND SAUCER, REGENCY SUGA...
# 5                             (REGENCY TEAPOT ROSES )
# 6   (GREEN REGENCY TEACUP AND SAUCER, REGENCY TEA ...
# 7                          (REGENCY TEA PLATE GREEN )
# 8   (REGENCY TEA PLATE GREEN , PINK REGENCY TEACUP...
# 9   (REGENCY TEA PLATE PINK, PINK REGENCY TEACUP A...
# 10                         (REGENCY TEA PLATE GREEN )
# 11                           (REGENCY TEA PLATE PINK)
# 12  (REGENCY TEA PLATE ROSES , PINK REGENCY TEACUP...
# 13                         (REGENCY TEA PLATE GREEN )
# 14  (REGENCY TEA PLATE ROSES , PINK REGENCY TEACUP...
# 15                           (REGENCY TEA PLATE PINK)
# 16  (REGENCY TEAPOT ROSES , REGENCY CAKESTAND 3 TIER)
# 17                         (REGENCY SUGAR BOWL GREEN)
# 18  (REGENCY TEA PLATE GREEN , REGENCY CAKESTAND 3...
# 19  (REGENCY TEA PLATE PINK, REGENCY CAKESTAND 3 T...
# 20                         (REGENCY TEA PLATE GREEN )
# 21                           (REGENCY TEA PLATE PINK)
# 22  (REGENCY TEA PLATE ROSES , REGENCY CAKESTAND 3...
# 23                         (REGENCY TEA PLATE GREEN )
# 24  (REGENCY TEA PLATE GREEN , REGENCY MILK JUG PI...
# 25   (REGENCY TEA PLATE PINK, REGENCY MILK JUG PINK )
# 26                         (REGENCY TEA PLATE GREEN )
# 27                           (REGENCY TEA PLATE PINK)
# 28  (REGENCY TEA PLATE ROSES , REGENCY MILK JUG PI...
# 29                         (REGENCY TEA PLATE GREEN )
#
#                                           consequents  antecedent support  \
# 0                          (REGENCY SUGAR BOWL GREEN)            0.070312
# 1                             (REGENCY TEAPOT ROSES )            0.093750
# 2                            (REGENCY TEA PLATE PINK)            0.082031
# 3                          (REGENCY TEA PLATE GREEN )            0.078125
# 4                             (REGENCY TEAPOT ROSES )            0.066406
# 5   (GREEN REGENCY TEACUP AND SAUCER, REGENCY SUGA...            0.070312
# 6                          (REGENCY TEA PLATE GREEN )            0.058594
# 7   (GREEN REGENCY TEACUP AND SAUCER, REGENCY TEA ...            0.082031
# 8                            (REGENCY TEA PLATE PINK)            0.054688
# 9                          (REGENCY TEA PLATE GREEN )            0.058594
# 10  (REGENCY TEA PLATE PINK, PINK REGENCY TEACUP A...            0.082031
# 11  (REGENCY TEA PLATE GREEN , PINK REGENCY TEACUP...            0.078125
# 12                         (REGENCY TEA PLATE GREEN )            0.054688
# 13  (REGENCY TEA PLATE ROSES , PINK REGENCY TEACUP...            0.082031
# 14                           (REGENCY TEA PLATE PINK)            0.054688
# 15  (REGENCY TEA PLATE ROSES , PINK REGENCY TEACUP...            0.078125
# 16                         (REGENCY SUGAR BOWL GREEN)            0.054688
# 17  (REGENCY TEAPOT ROSES , REGENCY CAKESTAND 3 TIER)            0.093750
# 18                           (REGENCY TEA PLATE PINK)            0.070312
# 19                         (REGENCY TEA PLATE GREEN )            0.062500
# 20  (REGENCY TEA PLATE PINK, REGENCY CAKESTAND 3 T...            0.082031
# 21  (REGENCY TEA PLATE GREEN , REGENCY CAKESTAND 3...            0.078125
# 22                         (REGENCY TEA PLATE GREEN )            0.070312
# 23  (REGENCY TEA PLATE ROSES , REGENCY CAKESTAND 3...            0.082031
# 24                           (REGENCY TEA PLATE PINK)            0.058594
# 25                         (REGENCY TEA PLATE GREEN )            0.058594
# 26   (REGENCY TEA PLATE PINK, REGENCY MILK JUG PINK )            0.082031
# 27  (REGENCY TEA PLATE GREEN , REGENCY MILK JUG PI...            0.078125
# 28                         (REGENCY TEA PLATE GREEN )            0.058594
# 29  (REGENCY TEA PLATE ROSES , REGENCY MILK JUG PI...            0.082031
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.093750  0.066406    0.944444  10.074074  0.059814   16.312500
# 1             0.070312  0.066406    0.708333  10.074074  0.059814    3.187500
# 2             0.078125  0.070312    0.857143  10.971429  0.063904    6.453125
# 3             0.082031  0.070312    0.900000  10.971429  0.063904    9.179688
# 4             0.070312  0.050781    0.764706  10.875817  0.046112    3.951172
# 5             0.066406  0.050781    0.722222  10.875817  0.046112    3.360937
# 6             0.082031  0.054688    0.933333  11.377778  0.049881   13.769531
# 7             0.058594  0.054688    0.666667  11.377778  0.049881    2.824219
# 8             0.078125  0.050781    0.928571  11.885714  0.046509   12.906250
# 9             0.082031  0.050781    0.866667  10.565079  0.045975    6.884766
# 10            0.058594  0.050781    0.619048  10.565079  0.045975    2.471191
# 11            0.054688  0.050781    0.650000  11.885714  0.046509    2.700893
# 12            0.082031  0.050781    0.928571  11.319728  0.046295   12.851563
# 13            0.054688  0.050781    0.619048  11.319728  0.046295    2.481445
# 14            0.078125  0.050781    0.928571  11.885714  0.046509   12.906250
# 15            0.054688  0.050781    0.650000  11.885714  0.046509    2.700893
# 16            0.093750  0.054688    1.000000  10.666667  0.049561         inf
# 17            0.054688  0.054688    0.583333  10.666667  0.049561    2.268750
# 18            0.078125  0.062500    0.888889  11.377778  0.057007    8.296875
# 19            0.082031  0.062500    1.000000  12.190476  0.057373         inf
# 20            0.062500  0.062500    0.761905  12.190476  0.057373    3.937500
# 21            0.070312  0.062500    0.800000  11.377778  0.057007    4.648438
# 22            0.082031  0.062500    0.888889  10.835979  0.056732    8.261719
# 23            0.070312  0.062500    0.761905  10.835979  0.056732    3.904687
# 24            0.078125  0.050781    0.866667  11.093333  0.046204    6.914063
# 25            0.082031  0.050781    0.866667  10.565079  0.045975    6.884766
# 26            0.058594  0.050781    0.619048  10.565079  0.045975    2.471191
# 27            0.058594  0.050781    0.650000  11.093333  0.046204    2.689732
# 28            0.082031  0.050781    0.866667  10.565079  0.045975    6.884766
# 29            0.058594  0.050781    0.619048  10.565079  0.045975    2.471191

# %%
spain_rules = do_association_rule(spain_frequent_items, "lift", 10)

print(len(spain_rules))
spain_rules.head(30)
# Out:
# 26
#                                           antecedents  \
# 0                   (GREEN REGENCY TEACUP AND SAUCER)
# 1                    (PINK REGENCY TEACUP AND SAUCER)
# 2                               (LUNCH BAG CARS BLUE)
# 3                           (LUNCH BAG  BLACK SKULL.)
# 4                         (POPPY'S PLAYHOUSE KITCHEN)
# 5                        (POPPY'S PLAYHOUSE BEDROOM )
# 6                     (POPPY'S PLAYHOUSE LIVINGROOM )
# 7                        (POPPY'S PLAYHOUSE BEDROOM )
# 8                     (POPPY'S PLAYHOUSE LIVINGROOM )
# 9                         (POPPY'S PLAYHOUSE KITCHEN)
# 10               (SET OF 6 GIRLS CELEBRATION CANDLES)
# 11               (SET/10 PINK POLKADOT PARTY CANDLES)
# 12  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 13  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 14                  (GREEN REGENCY TEACUP AND SAUCER)
# 15                   (PINK REGENCY TEACUP AND SAUCER)
# 16     (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)
# 17  (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...
# 18                              (LUNCH BAG CARS BLUE)
# 19                          (LUNCH BAG  BLACK SKULL.)
# 20  (POPPY'S PLAYHOUSE LIVINGROOM , POPPY'S PLAYHO...
# 21  (POPPY'S PLAYHOUSE LIVINGROOM , POPPY'S PLAYHO...
# 22  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...
# 23                    (POPPY'S PLAYHOUSE LIVINGROOM )
# 24                        (POPPY'S PLAYHOUSE KITCHEN)
# 25                       (POPPY'S PLAYHOUSE BEDROOM )
#
#                                           consequents  antecedent support  \
# 0                    (PINK REGENCY TEACUP AND SAUCER)            0.068182
# 1                   (GREEN REGENCY TEACUP AND SAUCER)            0.056818
# 2                           (LUNCH BAG  BLACK SKULL.)            0.068182
# 3                               (LUNCH BAG CARS BLUE)            0.056818
# 4                        (POPPY'S PLAYHOUSE BEDROOM )            0.079545
# 5                         (POPPY'S PLAYHOUSE KITCHEN)            0.090909
# 6                        (POPPY'S PLAYHOUSE BEDROOM )            0.056818
# 7                     (POPPY'S PLAYHOUSE LIVINGROOM )            0.090909
# 8                         (POPPY'S PLAYHOUSE KITCHEN)            0.056818
# 9                     (POPPY'S PLAYHOUSE LIVINGROOM )            0.079545
# 10               (SET/10 PINK POLKADOT PARTY CANDLES)            0.079545
# 11               (SET OF 6 GIRLS CELEBRATION CANDLES)            0.079545
# 12                   (PINK REGENCY TEACUP AND SAUCER)            0.068182
# 13                  (GREEN REGENCY TEACUP AND SAUCER)            0.056818
# 14  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.068182
# 15  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.056818
# 16                          (LUNCH BAG  BLACK SKULL.)            0.056818
# 17                              (LUNCH BAG CARS BLUE)            0.056818
# 18  (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...            0.068182
# 19     (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)            0.056818
# 20                       (POPPY'S PLAYHOUSE BEDROOM )            0.056818
# 21                        (POPPY'S PLAYHOUSE KITCHEN)            0.056818
# 22                    (POPPY'S PLAYHOUSE LIVINGROOM )            0.079545
# 23  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...            0.056818
# 24  (POPPY'S PLAYHOUSE LIVINGROOM , POPPY'S PLAYHO...            0.079545
# 25  (POPPY'S PLAYHOUSE LIVINGROOM , POPPY'S PLAYHO...            0.090909
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.056818  0.056818    0.833333  14.666667  0.052944    5.659091
# 1             0.068182  0.056818    1.000000  14.666667  0.052944         inf
# 2             0.056818  0.056818    0.833333  14.666667  0.052944    5.659091
# 3             0.068182  0.056818    1.000000  14.666667  0.052944         inf
# 4             0.090909  0.079545    1.000000  11.000000  0.072314         inf
# 5             0.079545  0.079545    0.875000  11.000000  0.072314    7.363636
# 6             0.090909  0.056818    1.000000  11.000000  0.051653         inf
# 7             0.056818  0.056818    0.625000  11.000000  0.051653    2.515152
# 8             0.079545  0.056818    1.000000  12.571429  0.052299         inf
# 9             0.056818  0.056818    0.714286  12.571429  0.052299    3.301136
# 10            0.079545  0.068182    0.857143  10.775510  0.061854    6.443182
# 11            0.079545  0.068182    0.857143  10.775510  0.061854    6.443182
# 12            0.056818  0.056818    0.833333  14.666667  0.052944    5.659091
# 13            0.068182  0.056818    1.000000  14.666667  0.052944         inf
# 14            0.056818  0.056818    0.833333  14.666667  0.052944    5.659091
# 15            0.068182  0.056818    1.000000  14.666667  0.052944         inf
# 16            0.056818  0.056818    1.000000  17.600000  0.053590         inf
# 17            0.068182  0.056818    1.000000  14.666667  0.052944         inf
# 18            0.056818  0.056818    0.833333  14.666667  0.052944    5.659091
# 19            0.056818  0.056818    1.000000  17.600000  0.053590         inf
# 20            0.090909  0.056818    1.000000  11.000000  0.051653         inf
# 21            0.079545  0.056818    1.000000  12.571429  0.052299         inf
# 22            0.056818  0.056818    0.714286  12.571429  0.052299    3.301136
# 23            0.079545  0.056818    1.000000  12.571429  0.052299         inf
# 24            0.056818  0.056818    0.714286  12.571429  0.052299    3.301136
# 25            0.056818  0.056818    0.625000  11.000000  0.051653    2.515152

# %%
netherlands_rules = do_association_rule(netherlands_frequent_items, "lift", 10)

print(len(netherlands_rules))
netherlands_rules.head(30)
# Out:
# 83484
#                                           antecedents  \
# 0                            (10 COLOUR SPACEBOY PEN)
# 1                  (FOOD CONTAINER SET 3 LOVE HEART )
# 2                           (LUNCH BAG  BLACK SKULL.)
# 3                        (3 HOOK HANGER MAGIC GARDEN)
# 4                        (BREAD BIN DINER STYLE RED )
# 5               (BUNDLE OF 3 ALPHABET EXERCISE BOOKS)
# 6                       (CHARLOTTE BAG APPLES DESIGN)
# 7                                  (JUMBO BAG APPLES)
# 8                         (DOLLY GIRL CHILDRENS BOWL)
# 9                           (SPACEBOY CHILDRENS BOWL)
# 10                           (SPACEBOY CHILDRENS CUP)
# 11                         (DOLLY GIRL CHILDRENS CUP)
# 12               (FOLDING BUTTERFLY MIRROR HOT PINK )
# 13                   (FOLDING BUTTERFLY MIRROR RED  )
# 14                             (IVORY KITCHEN SCALES)
# 15                              (MINT KITCHEN SCALES)
# 16                                   (JUMBO BAG OWLS)
# 17                          (JUMBO BAG PINK POLKADOT)
# 18                   (PACK OF 20 SKULL PAPER NAPKINS)
# 19                       (PACK OF 6 SKULL PAPER CUPS)
# 20                     (PACK OF 6 SKULL PAPER PLATES)
# 21                       (PACK OF 6 SKULL PAPER CUPS)
# 22                        (TV DINNER TRAY DOLLY GIRL)
# 23                          (SPACEBOY TV DINNER TRAY)
# 24  (CARD DOLLY GIRL , COWBOYS AND INDIANS BIRTHDA...
# 25                           (10 COLOUR SPACEBOY PEN)
# 26         (10 COLOUR SPACEBOY PEN, CARD DOLLY GIRL )
# 27  (CARD DOLLY GIRL , FOOD CONTAINER SET 3 LOVE H...
# 28                           (10 COLOUR SPACEBOY PEN)
# 29                 (FOOD CONTAINER SET 3 LOVE HEART )
#
#                                           consequents  antecedent support  \
# 0                  (FOOD CONTAINER SET 3 LOVE HEART )            0.053191
# 1                            (10 COLOUR SPACEBOY PEN)            0.095745
# 2                        (3 HOOK HANGER MAGIC GARDEN)            0.063830
# 3                           (LUNCH BAG  BLACK SKULL.)            0.074468
# 4               (BUNDLE OF 3 ALPHABET EXERCISE BOOKS)            0.063830
# 5                        (BREAD BIN DINER STYLE RED )            0.063830
# 6                                  (JUMBO BAG APPLES)            0.085106
# 7                       (CHARLOTTE BAG APPLES DESIGN)            0.053191
# 8                           (SPACEBOY CHILDRENS BOWL)            0.063830
# 9                         (DOLLY GIRL CHILDRENS BOWL)            0.095745
# 10                         (DOLLY GIRL CHILDRENS CUP)            0.085106
# 11                           (SPACEBOY CHILDRENS CUP)            0.063830
# 12                   (FOLDING BUTTERFLY MIRROR RED  )            0.053191
# 13               (FOLDING BUTTERFLY MIRROR HOT PINK )            0.053191
# 14                              (MINT KITCHEN SCALES)            0.085106
# 15                             (IVORY KITCHEN SCALES)            0.053191
# 16                          (JUMBO BAG PINK POLKADOT)            0.074468
# 17                                   (JUMBO BAG OWLS)            0.085106
# 18                       (PACK OF 6 SKULL PAPER CUPS)            0.074468
# 19                   (PACK OF 20 SKULL PAPER NAPKINS)            0.085106
# 20                       (PACK OF 6 SKULL PAPER CUPS)            0.074468
# 21                     (PACK OF 6 SKULL PAPER PLATES)            0.085106
# 22                          (SPACEBOY TV DINNER TRAY)            0.063830
# 23                        (TV DINNER TRAY DOLLY GIRL)            0.053191
# 24                           (10 COLOUR SPACEBOY PEN)            0.063830
# 25  (CARD DOLLY GIRL , COWBOYS AND INDIANS BIRTHDA...            0.053191
# 26                 (FOOD CONTAINER SET 3 LOVE HEART )            0.053191
# 27                           (10 COLOUR SPACEBOY PEN)            0.053191
# 28  (CARD DOLLY GIRL , FOOD CONTAINER SET 3 LOVE H...            0.053191
# 29         (10 COLOUR SPACEBOY PEN, CARD DOLLY GIRL )            0.095745
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.095745  0.053191    1.000000  10.444444  0.048099         inf
# 1             0.053191  0.053191    0.555556  10.444444  0.048099    2.130319
# 2             0.074468  0.053191    0.833333  11.190476  0.048438    5.553191
# 3             0.063830  0.053191    0.714286  11.190476  0.048438    3.276596
# 4             0.063830  0.053191    0.833333  13.055556  0.049117    5.617021
# 5             0.063830  0.053191    0.833333  13.055556  0.049117    5.617021
# 6             0.053191  0.053191    0.625000  11.750000  0.048665    2.524823
# 7             0.085106  0.053191    1.000000  11.750000  0.048665         inf
# 8             0.095745  0.063830    1.000000  10.444444  0.057718         inf
# 9             0.063830  0.063830    0.666667  10.444444  0.057718    2.808511
# 10            0.063830  0.063830    0.750000  11.750000  0.058397    3.744681
# 11            0.085106  0.063830    1.000000  11.750000  0.058397         inf
# 12            0.053191  0.053191    1.000000  18.800000  0.050362         inf
# 13            0.053191  0.053191    1.000000  18.800000  0.050362         inf
# 14            0.053191  0.053191    0.625000  11.750000  0.048665    2.524823
# 15            0.085106  0.053191    1.000000  11.750000  0.048665         inf
# 16            0.085106  0.063830    0.857143  10.071429  0.057492    6.404255
# 17            0.074468  0.063830    0.750000  10.071429  0.057492    3.702128
# 18            0.085106  0.074468    1.000000  11.750000  0.068130         inf
# 19            0.074468  0.074468    0.875000  11.750000  0.068130    7.404255
# 20            0.085106  0.063830    0.857143  10.071429  0.057492    6.404255
# 21            0.074468  0.063830    0.750000  10.071429  0.057492    3.702128
# 22            0.053191  0.053191    0.833333  15.666667  0.049796    5.680851
# 23            0.063830  0.053191    1.000000  15.666667  0.049796         inf
# 24            0.053191  0.053191    0.833333  15.666667  0.049796    5.680851
# 25            0.063830  0.053191    1.000000  15.666667  0.049796         inf
# 26            0.095745  0.053191    1.000000  10.444444  0.048099         inf
# 27            0.053191  0.053191    1.000000  18.800000  0.050362         inf
# 28            0.053191  0.053191    1.000000  18.800000  0.050362         inf
# 29            0.053191  0.053191    0.555556  10.444444  0.048099    2.130319

# %% [markdown]
# ## Individual Association Rule with Confidence

# %%
uk_con_rules = do_association_rule(uk_frequent_items, "confidence", 0.5)
germany_con_rules = do_association_rule(germany_frequent_items, "confidence", 0.5)
france_con_rules = do_association_rule(france_frequent_items, "confidence", 0.5)
eire_con_rules = do_association_rule(eire_frequent_items, "confidence", 0.5)
spain_con_rules = do_association_rule(spain_frequent_items, "confidence", 0.5)
netherlands_con_rules = do_association_rule(netherlands_frequent_items, "confidence", 0.5)

# %%
print(len(uk_con_rules))
uk_con_rules.head(30)
# Out:
# 30
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE RED )
# 2                (GARDENERS KNEELING PAD CUP OF TEA )
# 3                 (GARDENERS KNEELING PAD KEEP CALM )
# 4                   (GREEN REGENCY TEACUP AND SAUCER)
# 5                    (PINK REGENCY TEACUP AND SAUCER)
# 6                   (GREEN REGENCY TEACUP AND SAUCER)
# 7                  (ROSES REGENCY TEACUP AND SAUCER )
# 8                             (HEART OF WICKER LARGE)
# 9                    (JUMBO  BAG BAROQUE BLACK WHITE)
# 10                          (JUMBO BAG PINK POLKADOT)
# 11                             (JUMBO BAG STRAWBERRY)
# 12                           (JUMBO STORAGE BAG SUKI)
# 13                          (LUNCH BAG PINK POLKADOT)
# 14                          (LUNCH BAG PINK POLKADOT)
# 15                               (LUNCH BAG WOODLAND)
# 16                               (LUNCH BAG WOODLAND)
# 17                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 18                 (ROSES REGENCY TEACUP AND SAUCER )
# 19                   (PINK REGENCY TEACUP AND SAUCER)
# 20                 (RED HANGING HEART T-LIGHT HOLDER)
# 21                 (ROSES REGENCY TEACUP AND SAUCER )
# 22                      (WOODEN FRAME ANTIQUE WHITE )
# 23                (WOODEN PICTURE FRAME WHITE FINISH)
# 24  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 25  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 26  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 27                  (GREEN REGENCY TEACUP AND SAUCER)
# 28                 (ROSES REGENCY TEACUP AND SAUCER )
# 29                   (PINK REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                         (ALARM CLOCK BAKELIKE RED )            0.041614
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.045715
# 2                 (GARDENERS KNEELING PAD KEEP CALM )            0.037814
# 3                (GARDENERS KNEELING PAD CUP OF TEA )            0.044750
# 4                    (PINK REGENCY TEACUP AND SAUCER)            0.036910
# 5                   (GREEN REGENCY TEACUP AND SAUCER)            0.029733
# 6                  (ROSES REGENCY TEACUP AND SAUCER )            0.036910
# 7                   (GREEN REGENCY TEACUP AND SAUCER)            0.040890
# 8                             (HEART OF WICKER SMALL)            0.047705
# 9                           (JUMBO BAG RED RETROSPOT)            0.037754
# 10                          (JUMBO BAG RED RETROSPOT)            0.048972
# 11                          (JUMBO BAG RED RETROSPOT)            0.037513
# 12                          (JUMBO BAG RED RETROSPOT)            0.043423
# 13                          (LUNCH BAG  BLACK SKULL.)            0.051143
# 14                          (LUNCH BAG RED RETROSPOT)            0.051143
# 15                          (LUNCH BAG RED RETROSPOT)            0.040649
# 16                       (LUNCH BAG SPACEBOY DESIGN )            0.040649
# 17                  (PAPER CHAIN KIT 50'S CHRISTMAS )            0.040830
# 18                   (PINK REGENCY TEACUP AND SAUCER)            0.040890
# 19                 (ROSES REGENCY TEACUP AND SAUCER )            0.029733
# 20               (WHITE HANGING HEART T-LIGHT HOLDER)            0.038719
# 21                         (REGENCY CAKESTAND 3 TIER)            0.040890
# 22                (WOODEN PICTURE FRAME WHITE FINISH)            0.047283
# 23                      (WOODEN FRAME ANTIQUE WHITE )            0.051505
# 24                   (PINK REGENCY TEACUP AND SAUCER)            0.028708
# 25                 (ROSES REGENCY TEACUP AND SAUCER )            0.024365
# 26                  (GREEN REGENCY TEACUP AND SAUCER)            0.023099
# 27  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.036910
# 28  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...            0.040890
# 29  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.029733
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.045715  0.027381    0.657971  14.392899  0.025478    2.790071
# 1             0.041614  0.027381    0.598945  14.392899  0.025478    2.389660
# 2             0.044750  0.027622    0.730463  16.323179  0.025930    3.544034
# 3             0.037814  0.027622    0.617251  16.323179  0.025930    2.513879
# 4             0.029733  0.024365    0.660131  22.202084  0.023268    2.854825
# 5             0.036910  0.024365    0.819473  22.202084  0.023268    5.334871
# 6             0.040890  0.028708    0.777778  19.021141  0.027198    4.315994
# 7             0.036910  0.028708    0.702065  19.021141  0.027198    3.232551
# 8             0.055968  0.024003    0.503161   8.990200  0.021333    1.900075
# 9             0.087269  0.020928    0.554313   6.351808  0.017633    2.047921
# 10            0.087269  0.030517    0.623153   7.140632  0.026243    2.422019
# 11            0.087269  0.023822    0.635048   7.276942  0.020549    2.500965
# 12            0.087269  0.024606    0.566667   6.493366  0.020817    2.106303
# 13            0.060069  0.026657    0.521226   8.677164  0.023585    1.963206
# 14            0.067547  0.028406    0.555425   8.222763  0.024951    2.097400
# 15            0.067547  0.021953    0.540059   7.995289  0.019207    2.027333
# 16            0.052651  0.020867    0.513353   9.750181  0.018727    1.946687
# 17            0.056993  0.026355    0.645495  11.325873  0.024028    2.660066
# 18            0.029733  0.023099    0.564897  18.999094  0.021883    2.229970
# 19            0.040890  0.023099    0.776876  18.999094  0.021883    4.298556
# 20            0.113624  0.025813    0.666667   5.867304  0.021413    2.659128
# 21            0.085037  0.021229    0.519174   6.105266  0.017752    1.902898
# 22            0.051505  0.027622    0.584184  11.342330  0.025187    2.281044
# 23            0.047283  0.027622    0.536300  11.342330  0.025187    2.054597
# 24            0.029733  0.020566    0.716387  24.094129  0.019712    3.421090
# 25            0.040890  0.020566    0.844059  20.642108  0.019569    6.150482
# 26            0.036910  0.020566    0.890339  24.122088  0.019713    8.782466
# 27            0.023099  0.020566    0.557190  24.122088  0.019713    2.206139
# 28            0.024365  0.020566    0.502950  20.642108  0.019569    1.962850
# 29            0.028708  0.020566    0.691684  24.094129  0.019712    3.150310

# %%
print(len(germany_con_rules))
germany_con_rules.head(30)
# Out:
# 8
#                              antecedents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE )
# 1             (PLASTERS IN TIN SPACEBOY)
# 2     (PLASTERS IN TIN WOODLAND ANIMALS)
# 3          (RED RETROSPOT CHARLOTTE BAG)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 5   (ROUND SNACK BOXES SET OF 4 FRUITS )
# 6                  (SPACEBOY LUNCH BOX )
# 7               (WOODLAND CHARLOTTE BAG)
#
#                              consequents  antecedent support  \
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)            0.119639
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)            0.110609
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.142212
# 3               (WOODLAND CHARLOTTE BAG)            0.072235
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.252822
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.162528
# 6  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.106095
# 7  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.130926
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.142212  0.069977    0.584906  4.112908  0.052963    2.066489
# 1            0.142212  0.063205    0.571429  4.018141  0.047475    2.001505
# 2            0.252822  0.076749    0.539683  2.134637  0.040795    1.623181
# 3            0.130926  0.060948    0.843750  6.444504  0.051491    5.562077
# 4            0.162528  0.135440    0.535714  3.296131  0.094350    1.803785
# 5            0.252822  0.135440    0.833333  3.296131  0.094350    4.483070
# 6            0.252822  0.072235    0.680851  2.693009  0.045412    2.341159
# 7            0.252822  0.065463    0.500000  1.977679  0.032362    1.494357

# %%
rules.hist(figsize=[12,12], bins = 30)
plt.show()

# %%
df.groupby('Description') ['Quantity'].max().sort_values(ascending=False).head(10).plot(kind='bar')

## new cell
#dataframe.info
#dataframe.hist('StockCode')

#dataframe['StockCode'].value_counts().plot(kind='bar') works, but so many values
# try to plot only top 10

#https://stackoverflow.com/questions/15138973/how-to-get-the-number-of-the-most-frequent-value-in-a-column
print(df['Description'].value_counts().idxmax(), df['Description'].value_counts().max())  # Most frequent item and count

print("10 most frequent items DOESN'T account for quantity so not accurate")
df['Description'].value_counts().nlargest(n=10).plot(kind='barh')
df['Description'].value_counts().nlargest(n=10)
